# %%
import pickle
import pandas as pd
import sys
import time

# %% [markdown]
# Ładowanie pliku z błędami:

# %%
with open("../pickles/plewic_files_as_lists.p", 'rb') as input_pickle:
     revision_files = pickle.load(input_pickle)

# %% [markdown]
# `revision_files` jest to słownik. Klucz to nazwa pliku `.yaml`, natomiast jako wartość mamy listę błędów w danym pliku `.yaml`. Każdy błąd reprezentowany jest przez słownik:

# %%
revision_files['plewic.09.0138.yaml']
# Out:
# [{'text': 'Zawody odbywać się będą na torze olimpijskim w Igls, położonym około 4 km na południe od Innsbrucku, miasta-organizatora ZIOM 2012.',
#   'new_text': 'Zawody odbywać się będą na torze olimpijskim w Igls, położonym około 4 km na południe od Innsbrucka, miasta-organizatora ZIOM 2012.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Innsbrucku,',
#     'correction': 'Innsbrucka,',
#     'position': '16',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja'}}]},
#  {'text': 'Ślizg Dziewczyn Skeleton na Zimowych Igrzyskach Olimpijskich Młodzieży 2012 - ślizg dziewczyn',
#   'new_text': 'Ślizg Dziewcząt Skeleton na Zimowych Igrzyskach Olimpijskich Młodzieży 2012 - ślizg dziewcząt',
#   'valid_sentence': False,
#   'errors': [{'error': 'Dziewczyn',
#     'correction': 'Dziewcząt',
#     'position': '1',
#     'attributes': {'type': 'realword',
#      'distance': '2',
#      'category': 'semantyka/styl'}},
#    {'error': 'dziewczyn',
#     'correction': 'dziewcząt',
#     'position': '11',
#     'attributes': {'type': 'realword',
#      'distance': '2',
#      'category': 'semantyka/styl'}}]},
#  {'text': 'Początkowo nauczyciel w liceum Sisowatha.',
#   'new_text': 'Początkowo nauczyciel w Liceum Sisowatha.',
#   'valid_sentence': True,
#   'errors': [{'error': 'liceum',
#     'correction': 'Liceum',
#     'position': '3',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}}]},
#  {'text': 'Полежан) - najwyższy szczyt w górach Pirin, granotowy, ulokowany w obwodzie Błagoewgrad.',
#   'new_text': 'Полежан) - najwyższy szczyt w górach Pirin, granitowy, ulokowany w obwodzie Błagoewgrad.',
#   'valid_sentence': False,
#   'errors': [{'error': 'granotowy,',
#     'correction': 'granitowy,',
#     'position': '7',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'pisownia'}}]},
#  {'text': 'Natomiast między 15-19 lutego 2012 roku w ramach pucharu świata odbędzie się próba przedolimpijska w Soczi na stokach Krasnej Polany.',
#   'new_text': 'Natomiast między 15-19 lutego 2012 roku w ramach pucharu świata odbyła się próba przedolimpijska w Soczi na stokach Krasnej Polany.',
#   'valid_sentence': True,
#   'errors': [{'error': 'odbędzie',
#     'correction': 'odbyła',
#     'position': '10',
#     'attributes': {'type': 'realword',
#      'distance': '5',
#      'category': 'fleksja/czas'}}]},
#  {'text': 'św. Frydolin z Säckingen',
#   'new_text': 'Św. Frydolin z Säckingen',
#   'valid_sentence': False,
#   'errors': [{'error': 'św.',
#     'correction': 'Św.',
#     'position': '0',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}}]},
#  {'text': 'Tabliczka ta została została wykonana z mokrej gliny a nasepnie wysuszona tak by stwardniała.',
#   'new_text': 'Tabliczka ta została została wykonana z mokrej gliny a następnie wysuszona tak by stwardniała.',
#   'valid_sentence': True,
#   'errors': [{'error': 'nasepnie',
#     'correction': 'następnie',
#     'position': '9',
#     'attributes': {'type': 'nonword',
#      'distance': '2',
#      'category': 'pisownia/prawdopodobnie'}}]},
#  {'text': 'Tabliczka Wenus z czasów Ammi-saduqi (Enuma anu enlil, tablet 63) – zapis obserwacji Wenus pochodzących z drugiego tysiąclecia przed naszą erą wykonany pismem klinowym.',
#   'new_text': 'Tabliczka Wenus z czasów Ammi-saduqi (Enuma anu enlil, tablet 63) – zapis obserwacji Wenus pochodzących z drugiego tysiąclecia przed naszą erą, wykonany pismem klinowym.',
#   'valid_sentence': True,
#   'errors': [{'error': 'erą',
#     'correction': 'erą,',
#     'position': '20',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Tabliczka ta została została wykonana z mokrej gliny a następnie wysuszona tak by stwardniała.',
#   'new_text': 'Tabliczka ta została została wykonana z mokrej gliny, a następnie wysuszona tak, by stwardniała.',
#   'valid_sentence': True,
#   'errors': [{'error': 'gliny',
#     'correction': 'gliny,',
#     'position': '7',
#     'attributes': {'category': 'interpunkcja'}},
#    {'error': 'tak',
#     'correction': 'tak,',
#     'position': '11',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Rozpoczyna się przy ulicy Prymasa Stefana Wyszyńskiego, a na wysokości kościołą NMP rozwidla się.',
#   'new_text': 'Rozpoczyna się przy ulicy Prymasa Stefana Wyszyńskiego, a na wysokości kościoła NMP rozwidla się.',
#   'valid_sentence': True,
#   'errors': [{'error': 'kościołą',
#     'correction': 'kościoła',
#     'position': '10',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'znaki diakrytyczne'}}]},
#  {'text': 'Był absolwentem Akademii Wychowania Fizycznego we Wrocławiu, na której obronił również pracę doktorską.',
#   'new_text': 'Jest absolwentem Akademii Wychowania Fizycznego we Wrocławiu, na której obronił również pracę doktorską.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Był',
#     'correction': 'Jest',
#     'position': '0',
#     'attributes': {'type': 'realword',
#      'distance': '4',
#      'category': 'fleksja'}}]},
#  {'text': "! '... który polski błogosławiny czczony jest w São Paulo?'",
#   'new_text': "! '... który polski błogosławiony czczony jest w São Paulo?'",
#   'valid_sentence': False,
#   'errors': [{'error': 'błogosławiny',
#     'correction': 'błogosławiony',
#     'position': '3',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'pisownia'}}]},
#  {'text': "! '...jaki podstęp chcieli zastosować upowcy aby złamać Obronę Rybczy?'",
#   'new_text': "! '...jaki podstęp chcieli zastosować upowcy, aby złamać Obronę Rybczy?'",
#   'valid_sentence': False,
#   'errors': [{'error': 'upowcy',
#     'correction': 'upowcy,',
#     'position': '4',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': "! '...jak zapisał się w kartach II Wojny Światowej statek SS Athenia?'",
#   'new_text': "! '...jak zapisał się w kartach II wojny światowej statek SS Athenia?'",
#   'valid_sentence': False,
#   'errors': [{'error': 'Wojny Światowej',
#     'correction': 'wojny światowej',
#     'position': '6',
#     'attributes': {'type': 'multiword',
#      'distance': '2',
#      'category': 'wielkość liter'}}]},
#  {'text': "! '... do której gry, muzykę układał amerykański raper RZA?'",
#   'new_text': "! '... do której gry muzykę układał amerykański raper RZA?'",
#   'valid_sentence': False,
#   'errors': [{'error': 'gry,',
#     'correction': 'gry',
#     'position': '3',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': "! '... co robi księżycówka kilka dni po nowiu lub pełni księżyca?'",
#   'new_text': "! '... co robi księżycówka kilka dni po nowiu lub pełni Księżyca?'",
#   'valid_sentence': False,
#   'errors': [{'error': 'księżyca?',
#     'correction': 'Księżyca?',
#     'position': '10',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}}]},
#  {'text': "! '... w jaki sposób diagnozuje się Muszycę?'",
#   'new_text': "! '... w jaki sposób diagnozuje się muszycę?'",
#   'valid_sentence': False,
#   'errors': [{'error': 'Muszycę?',
#     'correction': 'muszycę?',
#     'position': '6',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}}]},
#  {'text': "! '... dlaczego jeden z odcinków linii Exeter - Plymouth jest uważany jedną z najdroższych w utrzymaniu tras kolejowych w Wielkiej Brytanii?'",
#   'new_text': "! '... dlaczego jeden z odcinków linii Exeter - Plymouth jest uważany za jedną z najdroższych w utrzymaniu tras kolejowych w Wielkiej Brytanii?'",
#   'valid_sentence': False,
#   'errors': [{'error': "''",
#     'correction': 'za',
#     'position': '11',
#     'attributes': {'type': 'insertion',
#      'distance': '2',
#      'category': 'przyimek'}}]},
#  {'text': "! '... proces galwanizacji blach stalowych opracowany przez polskiego wynalazcę jest stosowany na całym świecie?'",
#   'new_text': "! '... że proces galwanizacji blach stalowych opracowany przez polskiego wynalazcę jest stosowany na całym świecie?'",
#   'valid_sentence': False,
#   'errors': [{'error': "''",
#     'correction': 'że',
#     'position': '1',
#     'attributes': {'type': 'insertion',
#      'distance': '2',
#      'category': 'spójnik'}}]},
#  {'text': "! '... że NASA zleciło stworzenie gry komuterowej?'",
#   'new_text': "! '... że NASA zleciło stworzenie gry komputerowej?'",
#   'valid_sentence': False,
#   'errors': [{'error': 'komuterowej?',
#     'correction': 'komputerowej?',
#     'position': '6',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'pisownia'}}]},
#  {'text': "! '... że Zagłębienie Szeszupy znajduje się na terenie Suwalskiego Parku Narodowego i od roku 1978 jest obszarem chronionym?'",
#   'new_text': "! '... że Zagłębienie Szeszupy znajdujące się na terenie Suwalskiego Parku Narodowego od roku 1978 jest obszarem chronionym?'",
#   'valid_sentence': False,
#   'errors': [{'error': 'znajduje',
#     'correction': 'znajdujące',
#     'position': '4',
#     'attributes': {'type': 'realword',
#      'distance': '2',
#      'category': 'fleksja'}},
#    {'error': 'i',
#     'correction': "''",
#     'position': '11',
#     'attributes': {'type': 'deletion',
#      'distance': '1',
#      'category': 'spójnik'}}]},
#  {'text': "! '... dlaczego chińskiego cesarza Tongzhi próbowano skłócić z żoną??'",
#   'new_text': "! '... dlaczego chińskiego cesarza Tongzhi próbowano skłócić z żoną?'",
#   'valid_sentence': False,
#   'errors': [{'error': 'żoną??',
#     'correction': 'żoną?',
#     'position': '8',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': "! '... dlaczego za datę urodzenia Alemayeha Bezabeha uznaje się 1 stycznia 1986 roku?'",
#   'new_text': "! '... dlaczego za datę urodzenia Alemayehu Bezabeha uznaje się 1 stycznia 1986 roku?'",
#   'valid_sentence': False,
#   'errors': [{'error': 'Alemayeha',
#     'correction': 'Alemayehu',
#     'position': '5',
#     'attributes': {'type': 'unknown',
#      'distance': '1',
#      'category': 'nierozpoznany'}}]},
#  {'text': "! '... gdzie, według plotek znajdowano kości ludzkie, zbroje i łańcuchy?'",
#   'new_text': "! '... gdzie według plotek znajdowano kości ludzkie, zbroje i łańcuchy?'",
#   'valid_sentence': False,
#   'errors': [{'error': 'gdzie,',
#     'correction': 'gdzie',
#     'position': '1',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': "! '... jakie gatunki są chronione w Rezerwacie przyrody Jar Reknicy?'",
#   'new_text': "! '... jakie gatunki roślin są chronione w rezerwacie przyrody Jar Reknicy?'",
#   'valid_sentence': False,
#   'errors': [{'error': 'Rezerwacie',
#     'correction': 'rezerwacie',
#     'position': '6',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}}]},
#  {'text': "! '... w jakim kraju znajduje się najkrótsza sieć kolejowa świata.'",
#   'new_text': "! '... w którym kraju znajduje się najkrótsza sieć kolejowa świata?'",
#   'valid_sentence': False,
#   'errors': [{'error': 'jakim',
#     'correction': 'którym',
#     'position': '2',
#     'attributes': {'type': 'realword', 'distance': '5', 'category': 'styl'}},
#    {'error': 'świata.',
#     'correction': 'świata?',
#     'position': '9',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Pałace Krakowa - lista wszystkich zabytkowych pałacy znajdujących się w Krakowie',
#   'new_text': 'Pałace Krakowa – lista wszystkich zabytkowych pałaców znajdujących się w Krakowie',
#   'valid_sentence': False,
#   'errors': [{'error': 'pałacy',
#     'correction': 'pałaców',
#     'position': '6',
#     'attributes': {'type': 'nonword',
#      'distance': '2',
#      'category': 'pisownia/prawdopodobnie'}}]},
#  {'text': 'Oare Water - rzeka w Anglii w hrabstwie Somerset, razem z Badgworthy River tworzą rzekę West Lyn.',
#   'new_text': 'Oare Water - rzeka w Anglii w hrabstwie Somerset, razem z Badgeworthy River tworzą rzekę West Lyn.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Badgworthy',
#     'correction': 'Badgeworthy',
#     'position': '11',
#     'attributes': {'type': 'unknown',
#      'distance': '1',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'Odlew posągu wykonano w Zakładach Metalurgicznych "Pomet" w Poznaniu.',
#   'new_text': 'Odlew posągu wykonano w Zakłady Metalurgiczne "Pomet" w Poznaniu.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Zakładach Metalurgicznych',
#     'correction': 'Zakłady Metalurgiczne',
#     'position': '4',
#     'attributes': {'type': 'multiword',
#      'distance': '6',
#      'category': 'fleksja'}}]},
#  {'text': 'Odlew posągu wykonano w Zakłady Metalurgiczne "Pomet" w Poznaniu.',
#   'new_text': 'Odlew posągu wykonano w Zakłady Metalurgiczne "Pomet" w Poznań.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Poznaniu.',
#     'correction': 'Poznań.',
#     'position': '8',
#     'attributes': {'type': 'realword',
#      'distance': '3',
#      'category': 'fleksja'}}]},
#  {'text': 'Odlew posągu wykonano w Zakłady Metalurgiczne "Pomet" w Poznań.',
#   'new_text': 'Odlew posągu wykonano w Zakładach Metalurgicznych "Pomet" w Poznań.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Zakłady Metalurgiczne',
#     'correction': 'Zakładach Metalurgicznych',
#     'position': '4',
#     'attributes': {'type': 'multiword',
#      'distance': '6',
#      'category': 'fleksja'}}]},
#  {'text': 'Odlew posągu wykonano w Zakładach Metalurgicznych "Pomet" w Poznań.',
#   'new_text': 'Odlew posągu wykonano w Zakładach Metalurgicznych "Pomet" w Poznaniu.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Poznań.',
#     'correction': 'Poznaniu.',
#     'position': '8',
#     'attributes': {'type': 'realword',
#      'distance': '3',
#      'category': 'fleksja'}}]},
#  {'text': 'Pomnik Marii Konopnickiej - Pomnik odsłonięty został w 1979 r.',
#   'new_text': 'Pomnik Marii Konopnickiej - pomnik odsłonięty został w 1979 r.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Pomnik',
#     'correction': 'pomnik',
#     'position': '4',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}}]},
#  {'text': 'W dwóch pomieszczeniach i Sali głównej sufity drewniane.',
#   'new_text': 'W dwóch pomieszczeniach i sali głównej sufity drewniane.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Sali',
#     'correction': 'sali',
#     'position': '4',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}}]},
#  {'text': 'V Mistrzostwa Ameryki Południowej w piłce siatkowej kobiet odbyły się w 1962 roku w Santiago de Chle w Chile.',
#   'new_text': 'V Mistrzostwa Ameryki Południowej w piłce siatkowej kobiet odbyły się w 1962 roku w Santiago de Chile w Chile.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Chle',
#     'correction': 'Chile',
#     'position': '16',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'pisownia'}}]},
#  {'text': 'W skład Nadleśnictwa weszły części obrębów Glinik i Lubniewice z Nadlęśnictwa Skwierzyna oraz część obrębu Sulęcin z Nadlęśnictwa Ośno Lubuskie.',
#   'new_text': 'W skład Nadleśnictwa weszły części obrębów Glinik i Lubniewice z Nadleśnictwa Skwierzyna oraz część obrębu Sulęcin z Nadleśnictwa Ośno Lubuskie.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Nadlęśnictwa',
#     'correction': 'Nadleśnictwa',
#     'position': '10',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'znaki diakrytyczne'}},
#    {'error': 'Nadlęśnictwa',
#     'correction': 'Nadleśnictwa',
#     'position': '17',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'znaki diakrytyczne'}}]},
#  {'text': 'stacje i przystanki kolejowe w województwie lubelskim',
#   'new_text': 'Stacje i przystanki kolejowe w powiecie kraśnickim',
#   'valid_sentence': False,
#   'errors': [{'error': 'stacje',
#     'correction': 'Stacje',
#     'position': '0',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}}]},
#  {'text': 'Rzeżba na Akademii Sztuk Pięknych w La Massana; Barcelona.',
#   'new_text': 'Rzeźba na Akademii Sztuk Pięknych w La Massana; Barcelona',
#   'valid_sentence': False,
#   'errors': [{'error': 'Rzeżba',
#     'correction': 'Rzeźba',
#     'position': '0',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'znaki diakrytyczne'}},
#    {'error': 'Barcelona.',
#     'correction': 'Barcelona',
#     'position': '8',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Postanowieniem Prezydenta Rzeczypospolitej Polskiej z dnia 7 lipca 1997 otrzymał Złoty Krzyżem Zasługi.',
#   'new_text': 'Postanowieniem Prezydenta Rzeczypospolitej Polskiej z dnia 7 lipca 1997 otrzymał Złoty Krzyż Zasługi.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Krzyżem',
#     'correction': 'Krzyż',
#     'position': '11',
#     'attributes': {'type': 'realword',
#      'distance': '2',
#      'category': 'fleksja'}}]},
#  {'text': 'Jest bratem kmdr. dr. hab. inż. Wiesław Kicińskiego (ur. 1952), byłego profesora nadzwyczajnego i prodziekana Wydziału Nawigacji i Uzbrojenia Okrętowego w Akademii Marynarki Wojennej.',
#   'new_text': 'Jest bratem kmdr. dr. hab. inż. Wiesława Kicińskiego (ur. 1952), byłego profesora nadzwyczajnego i prodziekana Wydziału Nawigacji i Uzbrojenia Okrętowego w Akademii Marynarki Wojennej.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Wiesław',
#     'correction': 'Wiesława',
#     'position': '6',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'Jest również absolwentem studiów podyplomowych z zakresu zarządzania na Politechnice Gdańskiej.',
#   'new_text': 'Był również absolwentem studiów podyplomowych z zakresu zarządzania na Politechnice Gdańskiej.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Jest',
#     'correction': 'Był',
#     'position': '0',
#     'attributes': {'type': 'realword',
#      'distance': '4',
#      'category': 'fleksja/czas'}}]},
#  {'text': 'Jest bratem kmdr. dr. hab. inż. Wiesława Kicińskiego (ur. 1952), byłego profesora nadzwyczajnego i prodziekana Wydziału Nawigacji i Uzbrojenia Okrętowego w Akademii Marynarki Wojennej.',
#   'new_text': 'Był bratem kmdr. dr. hab. inż. Wiesława Kicińskiego (ur. 1952), byłego profesora nadzwyczajnego i prodziekana Wydziału Nawigacji i Uzbrojenia Okrętowego w Akademii Marynarki Wojennej.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Jest',
#     'correction': 'Był',
#     'position': '0',
#     'attributes': {'type': 'realword',
#      'distance': '4',
#      'category': 'fleksja/czas'}}]},
#  {'text': 'Penne – makaron typowy dla kuchni włoskiej pochodzący z południa Włoch.',
#   'new_text': 'Penne – makaron typowy dla kuchni włoskiej, pochodzący z południa Włoch.',
#   'valid_sentence': True,
#   'errors': [{'error': 'włoskiej',
#     'correction': 'włoskiej,',
#     'position': '6',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Podaje się go np. z owocami morza lub pesto.',
#   'new_text': 'Podaje się go np. z owocami morza lub z pesto.',
#   'valid_sentence': True,
#   'errors': [{'error': "''",
#     'correction': 'z',
#     'position': '8',
#     'attributes': {'type': 'insertion',
#      'distance': '1',
#      'category': 'przyimek'}}]},
#  {'text': 'Katastrofy lotnicze wg roku',
#   'new_text': 'Katastrofy lotnicze według roku',
#   'valid_sentence': False,
#   'errors': [{'error': 'wg',
#     'correction': 'według',
#     'position': '2',
#     'attributes': {'type': 'realword',
#      'distance': '4',
#      'category': 'notacja/skrót'}}]},
#  {'text': 'Jeśli szukasz wydarzeń, na których warto pojawić się z aparatem lub chciałbyś poinformować innych o takim wydarzeniu, zajrzyj na stronę Wydarzenia.',
#   'new_text': 'Jeśli szukasz wydarzeń, na których warto pojawić się z aparatem lub chcesz poinformować innych o takim wydarzeniu, zajrzyj na stronę Wydarzenia.',
#   'valid_sentence': True,
#   'errors': [{'error': 'chciałbyś',
#     'correction': 'chcesz',
#     'position': '11',
#     'attributes': {'type': 'realword',
#      'distance': '6',
#      'category': 'fleksja'}}]},
#  {'text': 'Jeśli chciałbyś wziąć udział w warsztatach fotograficznych organizowanych przez Stowarzyszenie Wikimedia Polska, zajrzyj na stronę Warsztaty',
#   'new_text': 'Jeśli chcesz wziąć udział w warsztatach fotograficznych organizowanych przez Stowarzyszenie Wikimedia Polska, zajrzyj na stronę Warsztaty',
#   'valid_sentence': False,
#   'errors': [{'error': 'chciałbyś',
#     'correction': 'chcesz',
#     'position': '1',
#     'attributes': {'type': 'realword',
#      'distance': '6',
#      'category': 'fleksja'}}]},
#  {'text': 'Jeśli poszukujesz lub chciałbyś zaoferować wypożyczenie literatury związanej z fotografia, zajrzyj na stronę Książki.',
#   'new_text': 'Jeśli poszukujesz lub chcesz zaoferować wypożyczenie literatury związanej z fotografia, zajrzyj na stronę Książki.',
#   'valid_sentence': True,
#   'errors': [{'error': 'chciałbyś',
#     'correction': 'chcesz',
#     'position': '3',
#     'attributes': {'type': 'realword',
#      'distance': '6',
#      'category': 'fleksja'}}]},
#  {'text': 'OpenBSD ships with the X window system and is suitable for use on the desktop.',
#   'new_text': 'OpenBSD ships with the X Window System and is suitable for use on the desktop.',
#   'valid_sentence': True,
#   'errors': [{'error': 'window system',
#     'correction': 'Window System',
#     'position': '5',
#     'attributes': {'type': 'multiword',
#      'distance': '2',
#      'category': 'wielkość liter'}}]},
#  {'text': 'orzec autobusowy w Suwałkach - dworzec służący komunikacji autobusowej z siedzibą w Suwałkach którego właścicielem jest PKS w Suwałkach.',
#   'new_text': 'Dworzec autobusowy w Suwałkach - dworzec służący komunikacji autobusowej z siedzibą w Suwałkach którego właścicielem jest PKS w Suwałkach.',
#   'valid_sentence': True,
#   'errors': [{'error': 'orzec',
#     'correction': 'Dworzec',
#     'position': '0',
#     'attributes': {'type': 'realword',
#      'distance': '2',
#      'category': 'składnia'}}]},
#  {'text': 'Aktywnie włączamy się w życie kulturalne regionu świętokrzyskiego.',
#   'new_text': 'Aktywnie włącza się w życie kulturalne regionu świętokrzyskiego.',
#   'valid_sentence': True,
#   'errors': [{'error': 'włączamy',
#     'correction': 'włącza',
#     'position': '1',
#     'attributes': {'type': 'realword',
#      'distance': '2',
#      'category': 'fleksja'}}]},
#  {'text': '1994 - wystawa poplenerowa w galerii "Zielona", BWA, Busko-Zdrój, Polska',
#   'new_text': '1994 - wystawa poplenerowa w galeria "Zielona", BWA, Busko-Zdrój, Polska',
#   'valid_sentence': False,
#   'errors': [{'error': 'galerii',
#     'correction': 'galeria',
#     'position': '5',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja'}}]},
#  {'text': '2002 - wystawa autorska w Staszowskim Ośrodku Kultury, Polska',
#   'new_text': '2002 - wystawa autorska w Staszowski Ośrodku Kultury, Polska',
#   'valid_sentence': False,
#   'errors': [{'error': 'Staszowskim',
#     'correction': 'Staszowski',
#     'position': '5',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja'}}]},
#  {'text': '2003 - wystawa autorska w galerii pałacu Sołtyków, Kurozwęki, Polska',
#   'new_text': '2003 - wystawa autorska w galerii pałac Sołtyków, Kurozwęki, Polska',
#   'valid_sentence': False,
#   'errors': [{'error': 'pałacu',
#     'correction': 'pałac',
#     'position': '6',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja'}}]},
#  {'text': '2004 - wystawa autorska w galerii "Winda", KCK, Kielce, Polska',
#   'new_text': '2004 - wystawa autorska w galeria "Winda", KCK, Kielce, Polska',
#   'valid_sentence': False,
#   'errors': [{'error': 'galerii',
#     'correction': 'galeria',
#     'position': '5',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja'}}]},
#  {'text': '2004- wystawa autorska na premierę filmu "Nikifor", Kinoplex, Polska',
#   'new_text': '2004- wystawa autorska na premierę film "Nikifor", Kinoplex, Polska',
#   'valid_sentence': False,
#   'errors': [{'error': 'filmu',
#     'correction': 'film',
#     'position': '5',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja'}}]},
#  {'text': '2005 - wystawa autorska w galerii "Piwnica", Staszów, Polska',
#   'new_text': '2005 - wystawa autorska w galeria "Piwnica", Staszów, Polska',
#   'valid_sentence': False,
#   'errors': [{'error': 'galerii',
#     'correction': 'galeria',
#     'position': '5',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja'}}]},
#  {'text': '2006 - wystawa autorska w galerii BWA w Ostrowcu Sw., Polska',
#   'new_text': '2006 - wystawa autorska w galeria BWA w Ostrowcu Sw., Polska',
#   'valid_sentence': False,
#   'errors': [{'error': 'galerii',
#     'correction': 'galeria',
#     'position': '5',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja'}}]},
#  {'text': '2006 - wystawa autorska w galerii CKiS, Połaniec, Polska',
#   'new_text': '2006 - wystawa autorska w galeria CKiS, Połaniec, Polska',
#   'valid_sentence': False,
#   'errors': [{'error': 'galerii',
#     'correction': 'galeria',
#     'position': '5',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja'}}]},
#  {'text': '2010 - Cykl akwareli dla Gazety Echo Dnia "Świętokrzyskie w akwareli" przy wsparciu Urzędu Marszałkowskiego w Kielcach, Polska',
#   'new_text': '2010 - Cykl akwareli dla Gazeta Echo Dnia "Świętokrzyskie w akwareli" przy wsparciu Urząd Marszałkowskiego w Kielcach, Polska',
#   'valid_sentence': False,
#   'errors': [{'error': 'Gazety',
#     'correction': 'Gazeta',
#     'position': '5',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja/liczba'}},
#    {'error': 'Urzędu',
#     'correction': 'Urząd',
#     'position': '13',
#     'attributes': {'type': 'realword',
#      'distance': '2',
#      'category': 'fleksja'}}]},
#  {'text': 'X flotylla Mas – flotylla Uderzeniowego Oddziału Specjalnego Marynarki po dowództwem księcia Junio Valerio Borghese.',
#   'new_text': 'X flotylla Mas – flotylla Uderzeniowego Oddziału Specjalnego Marynarki pod dowództwem księcia Junio Valerio Borghese.',
#   'valid_sentence': True,
#   'errors': [{'error': 'po',
#     'correction': 'pod',
#     'position': '9',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'przyimek'}}]},
#  {'text': 'Zwolennicy premiera Libanu Saad Hariri wyszli na ulice w proteście przeciwko Hezbollahowi w celu utworzenia kolejnego rządu.',
#   'new_text': 'Zwolennicy premiera Libanu Saada Hariri wyszli na ulice w proteście przeciwko Hezbollahowi, w celu utworzenia kolejnego rządu.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Saad',
#     'correction': 'Saada',
#     'position': '3',
#     'attributes': {'type': 'unknown',
#      'distance': '1',
#      'category': 'nierozpoznany'}},
#    {'error': 'Hezbollahowi',
#     'correction': 'Hezbollahowi,',
#     'position': '11',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Hezbollah i jego sojusznicy wcześniej zdobyli nominację ich kandydata Najib Mikati jako kolejnego premiera.',
#   'new_text': 'Hezbollah i jego sojusznicy wcześniej zdobyli nominację ich kandydata Najiba Mikati jako kolejnego premiera.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Najib',
#     'correction': 'Najiba',
#     'position': '9',
#     'attributes': {'type': 'unknown',
#      'distance': '1',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'W ramach systemu podziału władzy w Libanie, stanowisko premiera jest zarezerwowane dla sunnitów, a prezydent musi być chrześcijaninem maronitą, a przewodniczący parlamentu szyitą.',
#   'new_text': 'W ramach systemu podziału władzy w Libanie, stanowisko premiera jest zarezerwowane dla sunnitów, prezydent musi być chrześcijaninem maronitą, a przewodniczący parlamentu szyitą.',
#   'valid_sentence': True,
#   'errors': [{'error': 'a',
#     'correction': "''",
#     'position': '13',
#     'attributes': {'type': 'deletion',
#      'distance': '1',
#      'category': 'spójnik'}}]},
#  {'text': 'Hezbollah jest na oficjalnej amerykańskiej liście zagranicznych organizacji terrorystycznych i podlega sankcjami finansowymi i podróżnymi.',
#   'new_text': 'Hezbollah jest na oficjalnej amerykańskiej liście zagranicznych organizacji terrorystycznych i podlega sankcjom finansowym i podróżnym.',
#   'valid_sentence': True,
#   'errors': [{'error': 'sankcjami finansowymi',
#     'correction': 'sankcjom finansowym',
#     'position': '11',
#     'attributes': {'type': 'multiword',
#      'distance': '3',
#      'category': 'fleksja'}},
#    {'error': 'podróżnymi.',
#     'correction': 'podróżnym.',
#     'position': '14',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja/liczba'}}]},
#  {'text': 'Hezbollah i jego sojusznicy wcześniej zdobyli nominację ich kandydata Najiba Mikati jako kolejnego premiera.',
#   'new_text': 'Hezbollah i jego sojusznicy wcześniej zdobyli nominację ich kandydata Nażiba Mikati jako kolejnego premiera.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Najiba',
#     'correction': 'Nażiba',
#     'position': '9',
#     'attributes': {'type': 'unknown',
#      'distance': '1',
#      'category': 'nierozpoznany'}}]},
#  {'text': '! \'W Trypolis Mohammed Kabbara wezwał do "dniu gniewu" we wtorek, mówiąc: "Ta agresja wobec sunnitów i narodu jest nie do przyjęcia."\'',
#   'new_text': '! \'W Trypolis Mohammad Kabbara wezwał do "dniu gniewu" we wtorek, mówiąc: "Ta agresja wobec sunnitów i narodu jest nie do przyjęcia."\'',
#   'valid_sentence': False,
#   'errors': [{'error': 'Mohammed',
#     'correction': 'Mohammad',
#     'position': '2',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'Protestujący, którzy oskarżają ruch islamski o inscenizację zamachu stanu, blokują drogi i palą opon w kilku miastach.',
#   'new_text': 'Protestujący, którzy oskarżają ruch islamski o inscenizację zamachu stanu, blokują drogi i palą opony w kilku miastach.',
#   'valid_sentence': True,
#   'errors': [{'error': 'opon',
#     'correction': 'opony',
#     'position': '13',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja/liczba'}}]},
#  {'text': '! \'W Trypolis Mohammad Kabbara wezwał do "dniu gniewu" we wtorek, mówiąc: "Ta agresja wobec sunnitów i narodu jest nie do przyjęcia."\'',
#   'new_text': '! \'W Trypolisie Mohammad Kabbara wezwał do "dnia gniewu" we wtorek, mówiąc: "Ta agresja wobec sunnitów i narodu jest nie do przyjęcia."\'',
#   'valid_sentence': False,
#   'errors': [{'error': 'Trypolis',
#     'correction': 'Trypolisie',
#     'position': '1',
#     'attributes': {'type': 'realword',
#      'distance': '2',
#      'category': 'nierozpoznany'}},
#    {'error': '! \'"dniu\'',
#     'correction': '! \'"dnia\'',
#     'position': '6',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja'}}]},
#  {'text': 'Zwolennicy ustępującego premiera Libanu Saada Hariri wyszli na ulice w proteście przeciwko Hezbollahowi.',
#   'new_text': 'Zwolennicy ustępującego premiera Libanu Saada Haririego wyszli na ulice w proteście przeciwko Hezbollahowi.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Hariri',
#     'correction': 'Haririego',
#     'position': '5',
#     'attributes': {'type': 'unknown',
#      'distance': '3',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'Miało to związek z odmową zerwania współpracy z Trybunałem Specjalnym dla Libanu, który oskarżył członków Hezbollahu o udział w zamachu na Rafika Haririrego.',
#   'new_text': 'Miało to związek z odmową zerwania współpracy z Trybunałem Specjalnym dla Libanu, który oskarżył członków Hezbollahu o udział w zamachu na Rafiqa Haririrego.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Rafika',
#     'correction': 'Rafiqa',
#     'position': '21',
#     'attributes': {'type': 'unknown',
#      'distance': '1',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'Kawaleria nie ma możliwośći szarżowania na wroga, lecz staje do walki tak jak piechota.',
#   'new_text': 'Kawaleria nie ma możliwości szarżowania na wroga, lecz staje do walki tak jak piechota.',
#   'valid_sentence': True,
#   'errors': [{'error': 'możliwośći',
#     'correction': 'możliwości',
#     'position': '3',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'znaki diakrytyczne'}}]},
#  {'text': 'Można ją zwiększyć umieszczająć oddziały w trudnym (zalesionym, skalistym) terenie lub podnosząc morale (np. wysyłająć dowódcę w ich pobliże).',
#   'new_text': 'Można ją zwiększyć umieszczająć oddziały w trudnym (zalesionym, skalistym) terenie lub podnosząc morale (np. wysyłając dowódcę w ich pobliże).',
#   'valid_sentence': True,
#   'errors': [{'error': 'wysyłająć',
#     'correction': 'wysyłając',
#     'position': '14',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'znaki diakrytyczne'}}]},
#  {'text': "! 'Dotyczy również: :Kategoria:Literatura baroku , :Kategoria:Literatura średniowiecza, :Kategoria:Literatura oświecenia'",
#   'new_text': "! 'Dotyczy również: :Kategoria:Literatura baroku , :Kategoria:Literatura średniowiecza, :Kategoria:Literatura oświecenia.'",
#   'valid_sentence': True,
#   'errors': [{'error': 'oświecenia',
#     'correction': 'oświecenia.',
#     'position': '8',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Seria Zhu Zhu Pets składa się z modeli chomików nazywanych Mr. Squiggles, Pip Squeak, Num Nums, Chunk, Patches, Scoodles, Jilly, Nugget, Winkie, Cappuccino, Peachy, Jinx, Yo-Yo, Moo, Tex, Rocky, Spottie, Pinkie, Dezel, Bamboo, Hank, Captain Zhu, Carly, długowłosych Pax, Roxie, Ryder, Kingston, króliczków Fluffy i Sweetie, oraz nowej wojowniczej serii Kung.',
#   'new_text': 'Seria Zhu Zhu Pets składa się z modeli chomików nazywanych Mr. Squiggles, Pip Squeak, Num Nums, Chunk, Patches, Scoodles, Jilly, Nugget, Winkie, Cappuccino, Peachy, Jinx, Yo-Yo, Moo, Tex, Rocky, Spottie, Pinkie, Dezel, Bamboo, Hank, Captain Zhu, Carly, długowłosych Pax, Roxie, Ryder, Kingston, króliczków Fluffy i Sweetie oraz wprowadzonej w 2010 roku wojowniczej serii Kung.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Sweetie,',
#     'correction': 'Sweetie',
#     'position': '45',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Każdy z modeli różni się wyglądem, sposobem poruszania się, oraz dźwiękami jakie wydaje.',
#   'new_text': 'Każdy z modeli różni się wyglądem, sposobem poruszania się oraz wydawanymi dźwiękami.',
#   'valid_sentence': True,
#   'errors': [{'error': 'się,',
#     'correction': 'się',
#     'position': '8',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'W sprzedaży dostępne są także różnorodne akcesoria, ubranka, oraz elementy umożliwiające stworzenie osiedla dla chomików, będącego szeregiem pomieszczeń połączonych tunelami, które gryzonie potrafią sprawnie przeszukiwać.',
#   'new_text': 'W sprzedaży dostępne są także różnorodne akcesoria, ubranka oraz elementy umożliwiające stworzenie osiedla dla chomików, będącego szeregiem pomieszczeń połączonych tunelami, które gryzonie potrafią sprawnie przeszukiwać.',
#   'valid_sentence': True,
#   'errors': [{'error': 'ubranka,',
#     'correction': 'ubranka',
#     'position': '7',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Słowo Okil powstał z imienia reżyseria serialu - Okiła Khamidova.',
#   'new_text': 'Słowo Okil powstał z imienia reżysera serialu - Okiła Khamidova.',
#   'valid_sentence': True,
#   'errors': [{'error': 'reżyseria',
#     'correction': 'reżysera',
#     'position': '5',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'semantyka'}}]},
#  {'text': 'Słowo Okil powstał z imienia reżysera serialu - Okiła Khamidova.',
#   'new_text': 'Słowo Okil powstało od imienia reżysera serialu - Okiła Khamidova.',
#   'valid_sentence': True,
#   'errors': [{'error': 'powstał z',
#     'correction': 'powstało od',
#     'position': '2',
#     'attributes': {'type': 'multiword',
#      'distance': '3',
#      'category': 'fleksja'}}]},
#  {'text': 'Marka pojawiła się w odcinku 24, kiedy Polsat został oskarżony o reklamowanie marki Sony jako marka telewizora.',
#   'new_text': 'Marka pojawiła się w odcinku 24, kiedy Polsat został oskarżony o reklamowanie marki Sony jako marki telewizora.',
#   'valid_sentence': True,
#   'errors': [{'error': 'marka',
#     'correction': 'marki',
#     'position': '15',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja/liczba'}}]},
#  {'text': 'Wszystkie piosenki na płycie, z wyjątkiem "Love In Mind", zostały nagrane w trakcie mające 62 występy trasy koncertowej w pierwszej połowie (styczeń - kwiecień) 1973 roku.',
#   'new_text': 'Wszystkie piosenki na płycie, z wyjątkiem "Love In Mind", zostały nagrane w trakcie, mającej 62 występy, trasy koncertowej, w pierwszej połowie (styczeń - kwiecień) 1973 roku.',
#   'valid_sentence': True,
#   'errors': [{'error': 'trakcie mające',
#     'correction': 'trakcie, mającej',
#     'position': '12',
#     'attributes': {'type': 'multiword',
#      'distance': '1',
#      'category': 'nierozpoznany'}},
#    {'error': 'występy',
#     'correction': 'występy,',
#     'position': '15',
#     'attributes': {'category': 'interpunkcja'}},
#    {'error': 'koncertowej',
#     'correction': 'koncertowej,',
#     'position': '17',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Dlatego też bardziej elektryczne brzmienie Stacy Gators nie przypadło do gustu publiczności zgromadzonej na koncertach w 1973.',
#   'new_text': 'Dlatego też, bardziej elektryczne brzmienie Stacy Gators nie przypadło do gustu publiczności zgromadzonej na koncertach w 1973.',
#   'valid_sentence': True,
#   'errors': [{'error': 'też',
#     'correction': 'też,',
#     'position': '1',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'By w jakiś sposób zatuszować swoje problemy z głosem, dodał do wykonywanych utworów, partie gitar w wykonaniu David Crosbyego i Grahama Nasha.',
#   'new_text': 'By w jakiś sposób zatuszować swoje problemy z głosem, dodał do wykonywanych utworów, partie gitar w wykonaniu Davida Crosbyego i Grahama Nasha.',
#   'valid_sentence': True,
#   'errors': [{'error': 'David',
#     'correction': 'Davida',
#     'position': '17',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'Time Fades Away pozostaje jedynym z dwóch albumów Neila Younga nie wydanym na CD, drugim jest soundtrack do filmu Journey Through the Past.',
#   'new_text': 'Time Fades Away pozostaje jedynym z dwóch albumów Neila Younga, nie wydanym na CD - drugim jest soundtrack do filmu Journey Through the Past.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Younga',
#     'correction': 'Younga,',
#     'position': '9',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Obecnie oceniany jest, szczególnie przez fanów, dużo przychylniej, ale ma to prawdopodobnie związek z niedostępnością albumu i statusem "białego kruka".',
#   'new_text': 'Obecnie oceniany jest, szczególnie przez fanów, dużo przychylniej ale ma to prawdopodobnie związek z niedostępnością albumu i statusem "białego kruka".',
#   'valid_sentence': True,
#   'errors': [{'error': 'przychylniej,',
#     'correction': 'przychylniej',
#     'position': '7',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'W 2007 roku managment Neila Younga ogłosił że nie ma planów wydania tego nagrania na CD.',
#   'new_text': 'W 2007 roku managment Neila Younga ogłosił, że nie ma planów wydania tego nagrania na CD.',
#   'valid_sentence': True,
#   'errors': [{'error': 'ogłosił',
#     'correction': 'ogłosił,',
#     'position': '6',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Byłem wtedy bardziej zainteresowany surowym podejściem do muzyki, niż zaspokojeniem wymagań publiki która chciała drugiego Harvest .',
#   'new_text': 'Byłem wtedy bardziej zainteresowany surowym podejściem do muzyki, niż zaspokojeniem wymagań publiki, która chciała drugiego Harvest .',
#   'valid_sentence': True,
#   'errors': [{'error': 'publiki',
#     'correction': 'publiki,',
#     'position': '11',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Utwór "Time Fades Away" został wydany jako singiel na stronie B singla "Last Trip To Tulsa".',
#   'new_text': 'Utwór "Time Fades Away" został wydany jako singiel, na stronie B singla "Last Trip To Tulsa".',
#   'valid_sentence': True,
#   'errors': [{'error': 'singiel',
#     'correction': 'singiel,',
#     'position': '7',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': "Była to trasa emocjonalnie trudna dla Younga (między innnymi ze względu na śmierć Whittena), co doprowadziło do kłótni, w wyniku której zespoł opuścił perkusista - Kenneth'a Buttrey (został zastąpiony przez Johnnego Barbate, który gra we wszystkich utworach na płycie).",
#   'new_text': "Była to trasa emocjonalnie trudna dla Younga (między innymi ze względu na śmierć Whittena), co doprowadziło do kłótni, w wyniku której zespół opuścił perkusista - Kenneth'a Buttrey (został zastąpiony przez Johnny'ego Barbate, który gra we wszystkich utworach na płycie).",
#   'valid_sentence': True,
#   'errors': [{'error': 'innnymi',
#     'correction': 'innymi',
#     'position': '8',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'pisownia'}},
#    {'error': 'zespoł',
#     'correction': 'zespół',
#     'position': '21',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'znaki diakrytyczne'}}]},
#  {'text': 'Zespół R.E.M. uważa ten album za inspiracje do powstania płyty New Adventures in Hi-Fi.',
#   'new_text': 'Zespół R.E.M. uważa ten album za inspirację do powstania płyty New Adventures in Hi-Fi.',
#   'valid_sentence': True,
#   'errors': [{'error': 'inspiracje',
#     'correction': 'inspirację',
#     'position': '6',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'znaki diakrytyczne/kontekst'}}]},
#  {'text': "Śmierci Whittena wpłynęła znacząco na atmosferę zarówno trasy koncertowej, jak i następnych albumów Younga (szczególnie Tonight's the Night).",
#   'new_text': "Śmierć Whittena wpłynęła znacząco na atmosferę zarówno trasy koncertowej, jak i następnych albumów Younga (szczególnie Tonight's the Night).",
#   'valid_sentence': True,
#   'errors': [{'error': 'Śmierci',
#     'correction': 'Śmierć',
#     'position': '0',
#     'attributes': {'type': 'realword',
#      'distance': '2',
#      'category': 'fleksja'}}]},
#  {'text': 'Trasa koncertowa, której zapisem jest Time Fades Away odbyła się w momencie kiedy Young zyskał sobie przychylność fanów muzyki country (dzięki albumowi Harvest).',
#   'new_text': 'Trasa koncertowa, której zapisem jest Time Fades Away odbyła się w momencie, gdy Young zyskał sobie przychylność fanów muzyki country (dzięki albumowi Harvest).',
#   'valid_sentence': True,
#   'errors': [{'error': 'momencie kiedy',
#     'correction': 'momencie, gdy',
#     'position': '11',
#     'attributes': {'type': 'multiword',
#      'distance': '3',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'Inny członek zespołu, grający na elektrycznej gitarze stalowej Ben Keith był podobno tak pijany, że w trakcie jednego ze strojeń muzyków przed występem, zdawał się nie wiedzieć na którym instrumencie gra.',
#   'new_text': 'Inny członek zespołu, grający na elektrycznej gitarze stalowej Ben Keith był podobno tak pijany, że w trakcie jednego ze strojeń muzyków przed występem zdawał się nie wiedzieć, na którym instrumencie gra.',
#   'valid_sentence': True,
#   'errors': [{'error': 'występem,',
#     'correction': 'występem',
#     'position': '22',
#     'attributes': {'category': 'interpunkcja'}},
#    {'error': 'wiedzieć',
#     'correction': 'wiedzieć,',
#     'position': '26',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': "By w jakiś sposób zatuszować swoje problemy z głosem, dodał do wykonywanych utworów, partie gitar w wykonaniu Davida Crosby'ego i Grahama Nasha.",
#   'new_text': "By w jakiś sposób zatuszować swoje problemy z głosem, dodał do wykonywanych utworów partie gitar w wykonaniu Davida Crosby'ego i Grahama Nasha.",
#   'valid_sentence': True,
#   'errors': [{'error': 'utworów,',
#     'correction': 'utworów',
#     'position': '12',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': "Pianista, Jack Nitzschem narzekał, że grając nie słyszy sam siebie, ponieważ 12-strunowa gitara Crosby'ego zagłusza wszystko naokoło.",
#   'new_text': "Pianista, Jack Nitzsche narzekał, że grając nie słyszy sam siebie, ponieważ 12-strunowa gitara Crosby'ego zagłusza wszystko naokoło.",
#   'valid_sentence': True,
#   'errors': [{'error': 'Nitzschem',
#     'correction': 'Nitzsche',
#     'position': '2',
#     'attributes': {'type': 'unknown',
#      'distance': '1',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'Time Fades Away pozostaje jedynym z dwóch albumów Neila Younga, nie wydanym na CD - drugim jest soundtrack do filmu Journey Through the Past.',
#   'new_text': 'Time Fades Away pozostaje jedynym z dwóch albumów Neila Younga nie wydanym na CD - drugim jest soundtrack do filmu Journey Through the Past.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Younga,',
#     'correction': 'Younga',
#     'position': '9',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Wiadomo, że w [1995] roku były plany wydania płyty w formacie CD, podjęto nawet wstępne przymiarki, wypalono kilka egzemplarzy płyty jednakże, nie wiadomo czemu, ostatecznie płyta się nie ukazała .',
#   'new_text': 'Wiadomo, że w [1995] roku były plany wydania płyty w formacie CD, podjęto nawet wstępne przymiarki, wypalono kilka egzemplarzy płyty, jednakże, nie wiadomo czemu, ostatecznie płyta się nie ukazała .',
#   'valid_sentence': True,
#   'errors': [{'error': 'płyty',
#     'correction': 'płyty,',
#     'position': '19',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Zdecydowałem się mimo wszystko wydać tą płytę, tak, abyście mogli zobaczyć co się dzieję kiedy na chwilę straci się serce do grania.',
#   'new_text': 'Zdecydowałem się mimo wszystko wydać tę płytę, tak, abyście mogli zobaczyć co się dzieje, kiedy na chwilę straci się serce do grania.',
#   'valid_sentence': True,
#   'errors': [{'error': 'tą',
#     'correction': 'tę',
#     'position': '5',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja'}},
#    {'error': 'dzieję',
#     'correction': 'dzieje,',
#     'position': '13',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'znaki diakrytyczne/kontekst'}}]},
#  {'text': 'Byłem wtedy bardziej zainteresowany surowym podejściem do muzyki, niż zaspokojeniem wymagań publiki, która chciała drugiego Harvest .',
#   'new_text': 'Byłem wtedy bardziej zainteresowany surowym podejściem do muzyki niż zaspokojeniem wymagań publiki, która chciała drugiego Harvest .',
#   'valid_sentence': True,
#   'errors': [{'error': 'muzyki,',
#     'correction': 'muzyki',
#     'position': '7',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'MS Mazury – Drugi z serii masowców zbudowany dla Polskiej Żeglugi Morskiej w chińskiej stoczni Xingang w Tjanjin.',
#   'new_text': 'MS Mazury – drugi z serii masowców zbudowany dla Polskiej Żeglugi Morskiej w chińskiej stoczni Xingang w Tjanjin.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Drugi',
#     'correction': 'drugi',
#     'position': '3',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}}]},
#  {'text': 'Napędzany jest dwusuwowym, wysokoprężnym silnikie Diesela typu Sulzer 6RTA48T-B.',
#   'new_text': 'Napędzany jest dwusuwowym, wysokoprężnym silnikiem Diesla typu Sulzer 6RTA48T-B.',
#   'valid_sentence': True,
#   'errors': [{'error': 'silnikie Diesela',
#     'correction': 'silnikiem Diesla',
#     'position': '4',
#     'attributes': {'type': 'multiword',
#      'distance': '2',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'Imiona pierwszych 13 jednostek tej serii pochodza od polskich krain geograficznych.',
#   'new_text': 'Imiona pierwszych 13 jednostek tej serii pochodzą od polskich krain geograficznych.',
#   'valid_sentence': True,
#   'errors': [{'error': 'pochodza',
#     'correction': 'pochodzą',
#     'position': '6',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'znaki diakrytyczne'}}]},
#  {'text': 'To nowoczesny konstrukcyjnie Statek, odpowiadający wymaganiom najnowszych przepisów Międzynarodowej Organizacji Morza (IMO) oraz towarzystw klasyfikacyjnych.',
# ...
#   'valid_sentence': True,
#   'errors': [{'error': 'Jehowy',
#     'correction': 'Jehowy,',
#     'position': '10',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'W owym roku wydano we Francji broszurę Z misją w Afryce i rozpowszechniono ją urzędnikom państwowym i przedstawicielom środków masowego przekazu, by mogli się zapoznać z przykładami pomocy humanitarnej Świadków Jehowy na rzecz poszkodowanych w roku 1991, 1997 i 1998 w Demokratycznej Republice Konga, podobną pomoc zorganizowano dla uchodźców z Rwandy w 1994 roku, a w późniejszych latach uchodźcom w Tanzanii (2001-2002) oraz ofiarom wichur w 1999 roku.',
#   'new_text': 'W owym roku wydano we Francji broszurę Z misją w Afryce i rozpowszechniono ją urzędnikom państwowym i przedstawicielom środków masowego przekazu, by mogli się zapoznać z przykładami pomocy humanitarnej Świadków Jehowy na rzecz poszkodowanych w latach 1991, 1997 i 1998 w Demokratycznej Republice Konga, podobną pomoc zorganizowano dla uchodźców z Rwandy w 1994 roku, a w późniejszych latach uchodźcom w Tanzanii (2001-2002) oraz ofiarom wichur w 1999 roku.',
#   'valid_sentence': True,
#   'errors': [{'error': 'roku',
#     'correction': 'latach',
#     'position': '35',
#     'attributes': {'type': 'realword',
#      'distance': '6',
#      'category': 'fleksja'}}]},
#  {'text': '23 czerwca tegoż roku Rada Stanu (Conseil d’Etat), najwyższy sąd administracyjny Francji, wydała przełomowe orzeczenie.',
#   'new_text': '23 czerwca owego roku Rada Stanu (Conseil d’Etat), najwyższy sąd administracyjny Francji, wydała przełomowe orzeczenie.',
#   'valid_sentence': True,
#   'errors': [{'error': 'tegoż',
#     'correction': 'owego',
#     'position': '2',
#     'attributes': {'type': 'realword',
#      'distance': '3',
#      'category': 'składnia'}}]},
#  {'text': 'W roku 1978 na Gwadelupie zorganizowano kongres międzynarodowy z udziałem 6274 osoby, choć działało tam wówczas tylko 2600 Świadków Jehowy.',
#   'new_text': 'W roku 1978 na Gwadelupie zorganizowano kongres międzynarodowy z udziałem 6274 osób, choć działało tam wówczas tylko 2600 Świadków Jehowy.',
#   'valid_sentence': True,
#   'errors': [{'error': 'osoby,',
#     'correction': 'osób,',
#     'position': '11',
#     'attributes': {'type': 'realword',
#      'distance': '2',
#      'category': 'fleksja/liczba'}}]},
#  {'text': 'Kiedy film De Scheepsjongens van Bontekoe przyciągnął 100 000 widzów do kin, holenderska agencja prasowa Algemeen Nederlands Persbureau oglosiła, że film przekroczył „magiczną barierę 100 000 biletów”anp_|iii.',
#   'new_text': 'Kiedy film De Scheepsjongens van Bontekoe przyciągnął 100 000 widzów do kin, holenderska agencja prasowa Algemeen Nederlands Persbureau ogłosiła, że film przekroczył „magiczną barierę 100 000”anp_|iii.',
#   'valid_sentence': True,
#   'errors': [{'error': 'oglosiła,',
#     'correction': 'ogłosiła,',
#     'position': '18',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'znaki diakrytyczne'}}]},
#  {'text': 'Nagroda jest podobna do holenderskiej Złotej Płyty, którą przyznaje się po sprzedaży 40 000 singli, 35 000 albumów z muzyką rozrywkową lub 15 000 albumów z muzyką klasyczną.',
#   'new_text': 'Nagroda jest podobna do holenderskiej Złotej Płyty, którą przyznaje się po sprzedaży 40 000 singli, 35 000 albumów z muzyką rozrywkową lub 15 000 płyt z muzyką klasyczną.',
#   'valid_sentence': True,
#   'errors': [{'error': 'albumów',
#     'correction': 'płyt',
#     'position': '24',
#     'attributes': {'type': 'realword', 'distance': '7', 'category': 'styl'}}]},
#  {'text': 'Składa się ono z grubej kwadratowej ramki, w środku której znajduje się kadr z nagrodzonego filmu.',
#   'new_text': 'Składa się ona z grubej kwadratowej ramki, w środku której znajduje się kadr z nagrodzonego filmu.',
#   'valid_sentence': True,
#   'errors': [{'error': 'ono',
#     'correction': 'ona',
#     'position': '2',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja'}}]},
#  {'text': 'Co zaś do wycofania blokady to myślę, że czas na przemyślenie się jednak przyda, a dla jej zamianę "na dożywotnią", o czym pisałeś w mailu, to chyba gruba przesada.',
#   'new_text': 'Co zaś do wycofania blokady to myślę, że czas na przemyślenie się jednak przyda, a na jej zamianę "na dożywotnią", o czym pisałeś w mailu, to chyba gruba przesada.',
#   'valid_sentence': True,
#   'errors': [{'error': 'dla',
#     'correction': 'na',
#     'position': '15',
#     'attributes': {'type': 'realword',
#      'distance': '2',
#      'category': 'przyimek'}}]},
#  {'text': 'Zalew janowski - jest to sztuczny zbiornik wodny o powierzchni 30 ha, zlokalizowany na obrzeżach Lasów Janowskich, nieopodal miasta Janów Lubelski.',
#   'new_text': 'Zalew Janowski - jest to sztuczny zbiornik wodny o powierzchni 30 ha, zlokalizowany na obrzeżach Lasów Janowskich, nieopodal Janowa Lubelskiego.',
#   'valid_sentence': True,
#   'errors': [{'error': 'janowski',
#     'correction': 'Janowski',
#     'position': '1',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}}]},
#  {'text': 'Rys historyczny Na zlecenie władz polityczno-gospodarczych Powiatu Janowskiego opracowano roku 1963 dokumentacje techniczną, która miała na celu zmeliorowanie doliny rzeki Białka pod nazwa „Wydrzanka” o powierzchni 130 ha.',
#   'new_text': 'Rys historyczny Na zlecenie władz polityczno-gospodarczych powiatu janowskiego opracowano roku 1963 dokumentacje techniczną, która miała na celu zmeliorowanie doliny rzeki Białka pod nazwa „Wydrzanka” o powierzchni 130 ha.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Powiatu Janowskiego',
#     'correction': 'powiatu janowskiego',
#     'position': '6',
#     'attributes': {'type': 'multiword',
#      'distance': '2',
#      'category': 'wielkość liter'}}]},
#  {'text': 'Natężenie światła wynosi 1400 lx w głównym kierunku kamery i 1000 luksów na inne dziedziny sztuki są potrzebne, a na to system zapobiegania awarii energetycznych.',
#   'new_text': 'Natężenie światła wynosi 1400 lx w głównym kierunku kamery i 1000 luksów na inne dziedziny sztuki są potrzebne, na to system zapobiegania awarii energetycznych.',
#   'valid_sentence': True,
#   'errors': [{'error': 'a',
#     'correction': "''",
#     'position': '18',
#     'attributes': {'type': 'deletion',
#      'distance': '1',
#      'category': 'spójnik'}}]},
#  {'text': 'Wszystkie miejsca muszą być osoby, z folderów.',
#   'new_text': 'Wszystkie miejsca muszą być osobne, z folderów.',
#   'valid_sentence': True,
#   'errors': [{'error': 'osoby,',
#     'correction': 'osobne,',
#     'position': '4',
#     'attributes': {'type': 'realword',
#      'distance': '2',
#      'category': 'składnia'}}]},
#  {'text': 'Kategoryzacja stadionów UEFA jest to system punktacji stadionów piłkarskich w Europie utworzony przez Unię Europejskich Związków Piłkarskich (UEFA).',
#   'new_text': 'Kategoryzacja stadionów UEFA - system punktacji stadionów piłkarskich w Europie, utworzony przez Unię Europejskich Związków Piłkarskich (UEFA).',
#   'valid_sentence': True,
#   'errors': [{'error': 'Europie',
#     'correction': 'Europie,',
#     'position': '10',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Właścicielem jest norweski koncern medialny Schibsted.',
#   'new_text': 'Właścicielem jest norweski koncern mediowy Schibsted.',
#   'valid_sentence': True,
#   'errors': [{'error': 'medialny',
#     'correction': 'mediowy',
#     'position': '4',
#     'attributes': {'type': 'realword',
#      'distance': '3',
#      'category': 'semantyka'}}]},
#  {'text': 'W tej krwawej bitwie poległ Henryk Kurowski osłaniając z broni maszynowej odwrót swojego plutonu w kierunku lasów janowskich.',
#   'new_text': 'W tej krwawej bitwie poległ Henryk Kurowski osłaniając z broni maszynowej odwrót swojego plutonu w kierunku Lasów Janowskich.',
#   'valid_sentence': True,
#   'errors': [{'error': 'lasów janowskich.',
#     'correction': 'Lasów Janowskich.',
#     'position': '16',
#     'attributes': {'type': 'multiword',
#      'distance': '2',
#      'category': 'wielkość liter'}}]},
#  {'text': 'Doborowych oddziałów Wermacht i wydzielonej części 5 Dywizja Pancerna SS Wiking - dowodzonych całościowo przez SS-Gruppenführera Jakob Sporrenberg (głównodowodzący operacją "Maigewitter").',
#   'new_text': 'Doborowych oddziałów Wehrmacht i wydzielonej części 5 Dywizja Pancerna SS Wiking - dowodzonych całościowo przez SS-Gruppenführera Jakob Sporrenberg (głównodowodzący operacją "Maigewitter").',
#   'valid_sentence': True,
#   'errors': [{'error': 'Wermacht',
#     'correction': 'Wehrmacht',
#     'position': '2',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'Po ukończeniu tej podchorążówka zorganizowanej przez OP-44, uczestniczył w wielu akcjach skierowanych przeciwko hitlerowcom.',
#   'new_text': 'Po ukończeniu tej podchorążówki zorganizowanej przez OP-44, uczestniczył w wielu akcjach skierowanych przeciwko hitlerowcom.',
#   'valid_sentence': True,
#   'errors': [{'error': 'podchorążówka',
#     'correction': 'podchorążówki',
#     'position': '3',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'fleksja/liczba'}}]},
#  {'text': 'John Henry Ramistella (ur. 7 listopada 1942 w Nowym Jorku) – amerykański piosenkarz, kompozytor, autor tekstów i producent nagrań.',
#   'new_text': 'John Henry Ramistellaall (ur. 7 listopada 1942 w Nowym Jorku)all – amerykański piosenkarz, kompozytor, autor tekstów i producent nagrań.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Ramistella',
#     'correction': 'Ramistellaall',
#     'position': '2',
#     'attributes': {'type': 'unknown',
#      'distance': '3',
#      'category': 'nierozpoznany'}},
#    {'error': 'Jorku)',
#     'correction': 'Jorku)all',
#     'position': '9',
#     'attributes': {'type': 'unknown',
#      'distance': '3',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'Dzieło dedykowane było Gajuszowi Septycjuszowi Clausowi, prefektowi pretorianów, który był zarazem protektorem Swetoniusza.',
#   'new_text': 'Dzieło dedykowane było Gajuszowi Septycjuszowi Clarusowi, prefektowi pretorianów, który był zarazem protektorem Swetoniusza.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Clausowi,',
#     'correction': 'Clarusowi,',
#     'position': '5',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'Jest znany z działalności niepodległościowej i postawy patriotycznej, a działalności duszpasterskiej z płomiennych przemówień, wygłaszanych podczas kazań, jak również w czasie uroczystości narodowych.',
#   'new_text': 'Jest znany z działalności niepodległościowej i postawy patriotycznej, a w działalności duszpasterskiej z płomiennych przemówień, wygłaszanych podczas kazań, jak również w czasie uroczystości narodowych.',
#   'valid_sentence': True,
#   'errors': [{'error': "''",
#     'correction': 'w',
#     'position': '9',
#     'attributes': {'type': 'insertion',
#      'distance': '1',
#      'category': 'przyimek'}}]},
#  {'text': 'Godło Tuwy – symbol Republiki Tuwa przyjęty przez jej rząd 17 wrzęsnia 1992.',
#   'new_text': 'Godło Tuwy – symbol Republiki Tuwy przyjęty przez jej rząd 17 wrzęsnia 1992.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Tuwa',
#     'correction': 'Tuwy',
#     'position': '5',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'Obecnie barwy i wizerunek godła podlegają ustawie konstytucyjnej Republiki Tuwa od 31.12.1996.',
#   'new_text': 'Obecnie barwy i wizerunek godła podlegają ustawie konstytucyjnej Republiki Tuwy od 31 grudnia1996.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Tuwa',
#     'correction': 'Tuwy',
#     'position': '9',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'Barwa żółta (złota) symbolizuje bogactwo i sprawiedliwość państwa; również w żółtej (złotej) barwie zawarte jest odbicie historycznie tradycyjnych wierzeń religijnych części ludności Republiki Tuwa.',
#   'new_text': 'Barwa żółta (złota) symbolizuje bogactwo i sprawiedliwość państwa; również w żółtej (złotej) barwie zawarte jest odbicie historycznie tradycyjnych wierzeń religijnych części ludności Republiki Tuwy.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Tuwa.',
#     'correction': 'Tuwy.',
#     'position': '23',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'nierozpoznany'}}]},
#  {'text': 'W roku 1588 Zygmunt August ufundował w tym miejscu murowaną grekokatolicką świątynię ojców Bazylianów.',
#   'new_text': 'W roku 1588 Zygmunt August ufundował w tym miejscu murowaną grekokatolicką świątynię ojców bazylianów.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Bazylianów.',
#     'correction': 'bazylianów.',
#     'position': '13',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}}]},
#  {'text': 'Fasady i zakrystie zwieńczone późnorenesansowymi szczytami, wzorowanymi na szczycie kościoła Dominikanów.',
#   'new_text': 'Fasady i zakrystie zwieńczone późnorenesansowymi szczytami, wzorowanymi na szczycie kościoła dominikanów.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Dominikanów.',
#     'correction': 'dominikanów.',
#     'position': '10',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}}]},
#  {'text': 'katedry w Polsce prawosławie świątynie pod wezwaniem Przemienienia Lublin',
#   'new_text': 'Katedry w Polsce Prawosławie Świątynie pod wezwaniem Przemienienia Lublin',
#   'valid_sentence': False,
#   'errors': [{'error': 'katedry',
#     'correction': 'Katedry',
#     'position': '0',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}},
#    {'error': 'prawosławie świątynie',
#     'correction': 'Prawosławie Świątynie',
#     'position': '3',
#     'attributes': {'type': 'multiword',
#      'distance': '2',
#      'category': 'wielkość liter'}}]},
#  {'text': 'Pierwsza na cmentarzu przy ul. Lipowej, w części prawosławnej znajduję się cerkiew pw. Świętych Niewiast Niosących Wonności.',
#   'new_text': 'Pierwsza na cmentarzu przy ul. Lipowej, w części prawosławnej znajduje się cerkiew pw. Świętych Niewiast Niosących Wonności.',
#   'valid_sentence': True,
#   'errors': [{'error': 'znajduję',
#     'correction': 'znajduje',
#     'position': '9',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'znaki diakrytyczne/kontekst'}}]},
#  {'text': 'W XVII wieku kilkakrotnie zmieniała właścicieli i tyleż razy pełniła funkcje cerkwi grekokatolickiej i prawosławnej na przemian.',
#   'new_text': 'W XVII wieku kilkakrotnie zmieniała właścicieli i tyleż razy pełniła funkcje cerkwi greckokatolickiej i prawosławnej na przemian.',
#   'valid_sentence': True,
#   'errors': [{'error': 'grekokatolickiej',
#     'correction': 'greckokatolickiej',
#     'position': '12',
#     'attributes': {'type': 'nonword',
#      'distance': '1',
#      'category': 'pisownia'}}]},
#  {'text': 'Po kasacji Unii brzeskiej w Królestwie Polskim, stała się ponownie cerkwią prawosławną w 1875.',
#   'new_text': 'Po kasacji unii brzeskiej w Królestwie Polskim stała się ponownie cerkwią prawosławną w 1875.',
#   'valid_sentence': True,
#   'errors': [{'error': 'Unii',
#     'correction': 'unii',
#     'position': '2',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}},
#    {'error': 'Polskim,',
#     'correction': 'Polskim',
#     'position': '6',
#     'attributes': {'category': 'interpunkcja'}}]},
#  {'text': 'Do chwili odzyskania przez kościół prawosławny świątyni w Szczebrzeszynie była najstarszą nieprzerwanie istniejącą świątynią prawosławną w Polsce.',
#   'new_text': 'Do chwili odzyskania przez Kościół prawosławny świątyni w Szczebrzeszynie była najstarszą nieprzerwanie istniejącą świątynią prawosławną w Polsce.',
#   'valid_sentence': True,
#   'errors': [{'error': 'kościół',
#     'correction': 'Kościół',
#     'position': '4',
#     'attributes': {'type': 'realword',
#      'distance': '1',
#      'category': 'wielkość liter'}}]},
#  ...]

# %% [markdown]
# Kategorie błędów, które mnie interesują to: `pisownia`, `znaki diakrytyczne`, `znaki diakrytyczne/kontekst`, `składnia`, `fleksja/liczba`. Dodatkowo ograniczam się do tych, które są w dystansie edycji co najwyżej 1.

# %%
col_names = ['text_with_error', 'corrected_text', 'is_valid_sentence', 'error', 'correction', 'type', 'dist', 'category', 'file']

error_df = pd.DataFrame(columns=col_names)
error_df
# Out:
# Empty DataFrame
# Columns: [text_with_error, corrected_text, is_valid_sentence, error, correction, type, dist, category, file]
# Index: []

# %%
from IPython.display import clear_output

def update_progress(progress):
    bar_length = 20
    if isinstance(progress, int):
        progress = float(progress)
    if not isinstance(progress, float):
        progress = 0
    if progress < 0:
        progress = 0
    if progress >= 1:
        progress = 1
        
    block = int(round(bar_length * progress))

    clear_output(wait = True)
    text = "Progress: [{0}] {1:.1f}%".format( "#" * block + "-" * (bar_length - block), progress * 100)
    print(text)

# %% [markdown]
# ## Podejście multi

# %% [markdown]
# Mam listę kluczy słownika:

# %%
revision_files.keys()
# Out:
# dict_keys(['plewic.09.0138.yaml', 'plewic.07.0053.yaml', 'plewic.07.0019.yaml', 'plewic.01.0191.yaml', 'plewic.03.0025.yaml', 'plewic.01.0158.yaml', 'plewic.04.0019.yaml', 'plewic.09.0110.yaml', 'plewic.01.0095.yaml', 'plewic.09.0054.yaml', 'plewic.07.0129.yaml', 'plewic.03.0101.yaml', 'plewic.06.0005.yaml', 'plewic.09.0087.yaml', 'plewic.02.0120.yaml', 'plewic.03.0085.yaml', 'plewic.01.0247.yaml', 'plewic.02.0071.yaml', 'plewic.01.0224.yaml', 'plewic.01.0111.yaml', 'plewic.09.0023.yaml', 'plewic.03.0046.yaml', 'plewic.07.0005.yaml', 'plewic.01.0261.yaml', 'plewic.06.0037.yaml', 'plewic.01.0117.yaml', 'plewic.08.0007.yaml', 'plewic.04.0010.yaml', 'plewic.01.0104.yaml', 'plewic.01.0013.yaml', 'plewic.05.0051.yaml', 'plewic.01.0040.yaml', 'plewic.04.0023.yaml', 'plewic.01.0419.yaml', 'plewic.03.0029.yaml', 'plewic.08.0097.yaml', 'plewic.01.0323.yaml', 'plewic.03.0043.yaml', 'plewic.07.0057.yaml', 'plewic.08.0090.yaml', 'plewic.03.0016.yaml', 'plewic.01.0273.yaml', 'plewic.04.0089.yaml', 'plewic.01.0289.yaml', 'plewic.01.0140.yaml', 'plewic.01.0001.yaml', 'plewic.01.0125.yaml', 'plewic.02.0118.yaml', 'plewic.01.0300.yaml', 'plewic.01.0343.yaml', 'plewic.01.0274.yaml', 'plewic.02.0105.yaml', 'plewic.03.0087.yaml', 'plewic.07.0037.yaml', 'plewic.01.0363.yaml', 'plewic.06.0084.yaml', 'plewic.04.0038.yaml', 'plewic.02.0037.yaml', 'plewic.06.0010.yaml', 'plewic.07.0097.yaml', 'plewic.08.0078.yaml', 'plewic.09.0034.yaml', 'plewic.06.0070.yaml', 'plewic.08.0012.yaml', 'plewic.03.0089.yaml', 'plewic.03.0035.yaml', 'plewic.07.0131.yaml', 'plewic.09.0060.yaml', 'plewic.04.0085.yaml', 'plewic.04.0056.yaml', 'plewic.09.0116.yaml', 'plewic.02.0091.yaml', 'plewic.01.0054.yaml', 'plewic.01.0414.yaml', 'plewic.09.0044.yaml', 'plewic.01.0387.yaml', 'plewic.09.0128.yaml', 'plewic.07.0039.yaml', 'plewic.04.0107.yaml', 'plewic.05.0088.yaml', 'plewic.08.0014.yaml', 'plewic.01.0003.yaml', 'plewic.05.0018.yaml', 'plewic.01.0221.yaml', 'plewic.01.0094.yaml', 'plewic.02.0058.yaml', 'plewic.02.0114.yaml', 'plewic.09.0052.yaml', 'plewic.09.0117.yaml', 'plewic.07.0100.yaml', 'plewic.01.0163.yaml', 'plewic.02.0140.yaml', 'plewic.04.0065.yaml', 'plewic.01.0058.yaml', 'plewic.02.0005.yaml', 'plewic.01.0149.yaml', 'plewic.01.0240.yaml', 'plewic.02.0086.yaml', 'plewic.09.0102.yaml', 'plewic.03.0081.yaml', 'plewic.01.0189.yaml', 'plewic.09.0046.yaml', 'plewic.04.0026.yaml', 'plewic.08.0030.yaml', 'plewic.07.0013.yaml', 'plewic.06.0028.yaml', 'plewic.08.0077.yaml', 'plewic.01.0349.yaml', 'plewic.01.0269.yaml', 'plewic.07.0016.yaml', 'plewic.09.0007.yaml', 'plewic.07.0117.yaml', 'plewic.01.0242.yaml', 'plewic.01.0356.yaml', 'plewic.03.0063.yaml', 'plewic.02.0028.yaml', 'plewic.08.0098.yaml', 'plewic.09.0129.yaml', 'plewic.07.0022.yaml', 'plewic.09.0137.yaml', 'plewic.02.0106.yaml', 'plewic.01.0206.yaml', 'plewic.05.0042.yaml', 'plewic.01.0214.yaml', 'plewic.01.0169.yaml', 'plewic.02.0104.yaml', 'plewic.04.0011.yaml', 'plewic.01.0107.yaml', 'plewic.01.0062.yaml', 'plewic.07.0135.yaml', 'plewic.07.0090.yaml', 'plewic.01.0286.yaml', 'plewic.02.0065.yaml', 'plewic.08.0057.yaml', 'plewic.06.0017.yaml', 'plewic.07.0032.yaml', 'plewic.01.0390.yaml', 'plewic.06.0029.yaml', 'plewic.03.0024.yaml', 'plewic.01.0131.yaml', 'plewic.07.0069.yaml', 'plewic.01.0073.yaml', 'plewic.02.0070.yaml', 'plewic.02.0119.yaml', 'plewic.01.0246.yaml', 'plewic.08.0039.yaml', 'plewic.07.0105.yaml', 'plewic.01.0230.yaml', 'plewic.01.0186.yaml', 'plewic.06.0001.yaml', 'plewic.07.0031.yaml', 'plewic.03.0039.yaml', 'plewic.05.0060.yaml', 'plewic.02.0100.yaml', 'plewic.01.0302.yaml', 'plewic.01.0154.yaml', 'plewic.02.0063.yaml', 'plewic.02.0110.yaml', 'plewic.07.0071.yaml', 'plewic.07.0010.yaml', 'plewic.07.0026.yaml', 'plewic.05.0030.yaml', 'plewic.09.0058.yaml', 'plewic.05.0053.yaml', 'plewic.04.0003.yaml', 'plewic.02.0130.yaml', 'plewic.01.0162.yaml', 'plewic.02.0007.yaml', 'plewic.01.0137.yaml', 'plewic.05.0004.yaml', 'plewic.09.0045.yaml', 'plewic.02.0084.yaml', 'plewic.06.0081.yaml', 'plewic.02 ...

# %% [markdown]
# Chcę, żeby każdy z procesorów dostał część tych kluczy i wykonał zadanie (funkcję).

# %%
def get_error_dataframe(key):
    """
    Return a dataframe that consists of row - one for each error.
    Key represents one .yaml file.
    """
    categories_to_keep = set(["pisownia", "znaki diakrytyczne", "znaki diakrytyczne/kontekst", "składnia", "fleksja/liczba"])
    
    col_names = ['text_with_error', 'corrected_text', 'is_valid_sentence', 'error', 'correction', 'type', 'dist', 'category', 'file']
    error_df = pd.DataFrame(columns=col_names)
    
    row_to_insert = dict()
    row_to_insert['file'] = key
    for revision in revision_files[key]:
        # revision is a dictionary
        row_to_insert['text_with_error'] = revision['text']
        row_to_insert['corrected_text'] = revision['new_text']
        row_to_insert['is_valid_sentence'] = revision['valid_sentence']
        for error_dict in revision['errors']:
            # one revision may hold multiple revisions
            error_category = error_dict['attributes']['category']
            if error_category in categories_to_keep:
                row_to_insert['error'] = error_dict['error']
                row_to_insert['correction'] = error_dict['correction']
                row_to_insert['type'] = error_dict['attributes']['type']
                row_to_insert['dist'] = error_dict['attributes']['distance']
                row_to_insert['category'] = error_category
                # add row to the dataframe
                error_df.loc[len(error_df)] = row_to_insert
    return error_df

# %%
few_keys = list(revision_files.keys())[:15]

# %% [markdown]
# Podejście asynchroniczne:

# %%
import multiprocessing as mp

t0 = time.time()
pool = mp.Pool(processes=6)

results = [pool.apply_async(get_error_dataframe, args=(file_name,)) for file_name in revision_files.keys()]

big_data_frame = pd.concat([res.get() for res in results], axis=0)
t1 = time.time()

total_async = t1- t0
print(total_async)
# Out:
# 401.48740005493164

# %%
big_data_frame.shape
# Out:
# (609572, 9)

# %%
big_data_frame.reset_index(drop=True)

# %%
with open("./pickles/chosen_errors.p", "wb") as file:
    pickle.dump(big_data_frame, file, protocol=pickle.HIGHEST_PROTOCOL)
